# %%
from moviepy.editor import VideoFileClip

# %%
challenge_output = 'clip_out.mp4'
clip1 = VideoFileClip('challenge_video.mp4')
clip1.write_videofile(challenge_output, audio=False)
clip1.write_images_sequence('clip_c/clipc%04d.jpeg')
# Out:
# [MoviePy] >>>> Building video clip_out.mp4
# [MoviePy] Writing video clip_out.mp4
# 100%|████████████████████████████████████████████████████████████████████████████████| 485/485 [00:08<00:00, 57.83it/s]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: clip_out.mp4
#
# [MoviePy] Writing frames clip_c/clipc%04d.jpeg.
# 485it [00:24, 19.99it/s]
# [MoviePy]: Done writing frames clip_c/clipc%04d.jpeg.
# ['clip_c/clipc0000.jpeg',
#  'clip_c/clipc0001.jpeg',
#  'clip_c/clipc0002.jpeg',
#  'clip_c/clipc0003.jpeg',
#  'clip_c/clipc0004.jpeg',
#  'clip_c/clipc0005.jpeg',
#  'clip_c/clipc0006.jpeg',
#  'clip_c/clipc0007.jpeg',
#  'clip_c/clipc0008.jpeg',
#  'clip_c/clipc0009.jpeg',
#  'clip_c/clipc0010.jpeg',
#  'clip_c/clipc0011.jpeg',
#  'clip_c/clipc0012.jpeg',
#  'clip_c/clipc0013.jpeg',
#  'clip_c/clipc0014.jpeg',
#  'clip_c/clipc0015.jpeg',
#  'clip_c/clipc0016.jpeg',
#  'clip_c/clipc0017.jpeg',
#  'clip_c/clipc0018.jpeg',
#  'clip_c/clipc0019.jpeg',
#  'clip_c/clipc0020.jpeg',
# ...
